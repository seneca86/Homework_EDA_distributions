# %% [markdown]
# ## Homework pandas review
# ### Instructions

# %% [markdown]
# * You will provide a .py into Turnitin, either uploaded or copy-pasted into the text prompt; it is critical that the code runs (i.e. if I press the "Run" button there should be no error message) - if it does not, you will lose most of the grade
#
# * If you do not know how to answer a question, just skip it or write something simple that works (even if uncomplete), but please do not leave a piece of code that breaks
#
# * You do not need to write text, just code; please print important results (otherwise they are executed but do not get printed)
#
# * Doing the assignments in groups is strongly recommended; please do not copy among different groups: if I detect errors that have been copy pasted and that are suspiciously similar across different submission the grade will be penalized
#
# * Just send one submission per group includind the names of the memembers
#
# * You may use whatever IDE you want (VSCode, Replit, or GitHub Codespaces), but the submission of the file must be done through Turnitin in Blackboard
#
# * When I ask you to "comment" on something, just write one or two concise lines, and actually comment the lines (prepend a # symbol); please be crisp and avoid long paragraphs
#
# * If there are several ways to do something, or the instructions are open-ended, please use your freedom; creativity will receive bonus points

# %% [markdown]
# ### Questions
# (1) Load the following libraries and settings

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

sns.set_theme()

# %%
matplotlib.rcParams["axes.labelsize"] = 14
matplotlib.rcParams["xtick.labelsize"] = 12
matplotlib.rcParams["ytick.labelsize"] = 12
matplotlib.rcParams["text.color"] = "k"
matplotlib.rcParams["figure.dpi"] = 200

# %% [markdown]
# (2) Create a folder to store the images, like we did in class
#
# (3) Read the `housing.csv` file that you can find in this repository
#
# (4) Print the columns of the dataset, as well as the first few rows with the `head()` command, and some summary statistics with the `info()` command
#
# (5) Count the occurences of each value of the column `ocean_proximity`
#
# (6) Add new columns that contain the number of rooms per household, the number of bedrooms per room, and the population per household
#
# (7) Substitute values of population per household greater than 20 with a `nan`
#
# (8) Plot histograms for three variables of your choice
#
# (9) Plot a scatterplot with the longitude and latitude as `x` and `y` variables, and the `median_house_value` as the `hue`; use the command `sns.scatterplot`; use `help(sns.scatterplot)` for more details
#
# (10) Plot a `relplot` with the longitude and latitude as `x` and `y` variables; experiment with the rest; use `help(sns.relplot)` for more details
